# %%
import pandas as pd

# %%
df = pd.read_csv("/home/cavid/Desktop/Alienide/All_project/Python-Crash-Course-/pandas/Dataset/nyc_weather.csv")

# %%
df.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/1/2016           38        23        52                 30.03
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# ...

# %%
df["Temperature"].max()
# Out:
# 50

# %%
df["EST"][df["Events"] =="Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df["WindSpeedMPH"].mean() # mean=average
# Out:
# 6.892857142857143

# %% [markdown]
# ## Data Munging : (all Nan value shoud be 0)

# %%
df.fillna(0, inplace=True)

# %%
df.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/1/2016           38        23        52                 30.03
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5      0
# 1               10           7.0               0           3      0
# ...

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.head(10)[["EST","DewPoint"]]
# Out:
#          EST  DewPoint
# 0   1/1/2016        23
# 1   1/2/2016        18
# 2   1/3/2016        21
# 3   1/4/2016         9
# 4   1/5/2016        -3
# 5   1/6/2016         4
# 6   1/7/2016        11
# 7   1/8/2016        29
# 8   1/9/2016        38
# 9  1/10/2016        46

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.225806    3.129032      247.129032
# std           1.939405      3.422569    2.629853       92.308086
# min           1.000000      0.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df[df.Temperature>=45]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                 4           0.0             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 30               10           5.0               0           0      0
#
#     WindDirDegrees
# 9              109
# 15             340
# 30             241

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           0.0             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df["EST"][df.Temperature==df.Temperature.max()]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
df[["EST","Temperature"]][df.Temperature==df.Temperature.max()]
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5      0
# 1               10           7.0               0           3      0
# 2               10           8.0               0           1      0
# 3               10           9.0               0           3      0
# 4               10           5.0               0           0      0
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
weather_data = {
    "day" : ["1/1/2017","1/2/2017","22/2/2019"],
    "temperature" : [32,33,34],
    "windspeed": ["Rain","Sunny", "Snow"]
}
df_dictionary = pd.DataFrame(weather_data)
df_dictionary
# Out:
#          day  temperature windspeed
# 0   1/1/2017           32      Rain
# 1   1/2/2017           33     Sunny
# 2  22/2/2019           34      Snow
